# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharth2004agrawal/AiProject1/blob/AiModules%2Fmodule-8/Day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
xpoints=np.array([1,4,3])
ypoints=np.array([2,9,2])

# %%
plt.scatter(xpoints,ypoints)
plt.savefig('xyz2.png')
plt.show()

# %%
plt.savefig('xyz.png')

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# %%
plt.scatter(x,y)
plt.savefig('xyz3.png')
plt.show()

# %%
x1=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x1,y1,color='red')

x2=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y2=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

plt.scatter(x2,y2,color='green')
plt.savefig('xyz4.png')
plt.show()

# %%
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
colors=np.random.randint(100,size=(100))
sizes=10*np.random.randint(100,size=(100))
plt.scatter(x,y,c=colors,s=sizes,alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
plt.savefig('xyz5.png')
plt.show()

# %%
xpoints=np.array([1,4,3])
ypoints=np.array([2,9,2])
plt.plot(xpoints,ypoints)
plt.savefig('xyz6.png')
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.savefig('xyz7.png')
plt.show()

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
digits = load_digits()

# %%
print(f"image data shape:{digits.data.shape}")
print(f"Target shape:{digits.target.shape}")
print(f"Number of samples:{len(digits.images)}")
# Out:
# image data shape:(1797, 64)
# Target shape:(1797,)
# Number of samples:1797

# %%
fig, axes = plt.subplots(nrows=1,ncols=5, figsize=(10,3))
for ax,image,label in zip(axes, digits.images,digits.target):
  ax.set_axis_off()
  ax.imshow(image,cmap=plt.cm.gray_r,interpolation='nearest')
  ax.set_title(f'Training:{label}')
plt.tight_layout()
plt.show()

# %%
n_samples=len(digits.images)
x=digits.images.reshape((n_samples,-1))
y=digits.target
print(f"Flattened data shape:{x.shape}")
# Out:
# Flattened data shape:(1797, 64)

# %%
scaler=StandardScaler()
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)
print(f"Training data shape:{x_train_scaled.shape}")
print(f"Test data shape:{x_test_scaled.shape}")
# Out:
# Training data shape:(1203, 64)
# Test data shape:(594, 64)

# %%
 model=LogisticRegression(max_iter=10000,solver='liblinear',random_state=42)
 model.fit(x_train_scaled,y_train)
 print("Model training complete !")
# Out:
# Model training complete !

# %%
y_pred=model.predict(x_test_scaled)
accuracy=accuracy_score(y_test,y_pred)
print("\nAccuracy :{accuracy:.4f}")
print("\classifciation report :")
print(classification_report(y_test,y_pred))
# Out:
# Accuracy :{accuracy:.4f}
# \classifciation report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        55
#            1       0.91      0.95      0.93        55
#            2       0.93      1.00      0.96        52
#            3       0.98      0.95      0.96        56
#            4       1.00      0.98      0.99        64
#            5       0.97      0.93      0.95        73
#            6       0.98      0.98      0.98        57
#            7       0.98      0.98      0.98        62
#            8       0.89      0.92      0.91        52
#            9       0.97      0.94      0.96        68
#
#     accuracy                           0.96       594
#    macro avg       0.96      0.96      0.96       594
# weighted avg       0.96      0.96      0.96       594
# <>:4: SyntaxWarning: invalid escape sequence '\c'
# <>:4: SyntaxWarning: invalid escape sequence '\c'
# ...

# %% [markdown]
# # Day 9

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.linspace(-1.5,1.5,30)
y=x**2
px=0.8
py=px**2

# %%
plt.plot(x,y,"g-",px,py,"ro")
plt.text(0,1.5,"Square function\n$y=x^2$",fontsize=20,color='red',horizontalalignment="center")
plt.text(px-0.08,py,"Beautiful point",ha="right",weight="heavy")
plt.text(px,py,"x=%0.2f\ny=%0.2f"%(px,py),rotation=50,color="gray")
plt.show()

# %%
 x=np.linspace(-1.5,1.5,30)
 y=2*(x**2)-3*x+1

# %%
plt.plot(x,y,"g-")
plt.savefig("quad.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
plt.title("body data",fontdict=font1)
plt.xlabel("Weight",fontdict=font2)
plt.ylabel("Height",fontdict=font2)
plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# # Markers

# %%
import numpy as np
import matplotlib.pyplot as plt
markers=['.',',','o','v','^','<','>','1','2','3','4','8','s','p','*','+','x','D','d','|','_']

# %%
plt.figure(figsize=(13,10))
samples=range(len(markers))
for i in samples:
  plt.plot([i-1,i,i+1],[i,i,i],label=markers[i],marker=markers[i],markersize=10)
  plt.title('Matplotlib Marker styles',fontsize=20)
  plt.ylim([-1,len(markers)+1])
  plt.legend(loc='lower right')
  plt.show()
# Out:
# /tmp/ipykernel_945/2532615734.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='lower right')

# %%
 from sklearn.datasets import make_classification
 from sklearn.model_selection import train_test_split
 from sklearn.preprocessing import StandardScaler
 from sklearn.linear_model import LogisticRegression
 from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
 import matplotlib.pyplot as plt
 import seaborn as sns
 import numpy as np

# %%
X_waste,y_waste = make_classification(
    n_samples=1000,
    n_features=10,
    n_redundant=2,
    n_informative=5,
    n_classes=3,
    random_state=42,
    n_clusters_per_class=1,
)
print(f"Synthetic waste data shape:{X_waste.shape}")
print(f"Target waste target shape:{y_waste.shape}")
print(f"Number of samples:{len(X_waste)}")
print(f"Number of classes:{len(np.unique(y_waste))}")
# Out:
# Synthetic waste data shape:(1000, 10)
# Target waste target shape:(1000,)
# Number of samples:1000
# Number of classes:3
