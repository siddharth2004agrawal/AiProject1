# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharth2004agrawal/AiProject1/blob/AiModules%2Fmodule-6/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import make_classification

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# ## Generate a sythentic dataset

# %%
 x,y=make_classification(
     n_samples=1000,
     n_features=2,
     n_informative=2,
     n_redundant=0,
     n_clusters_per_class=1,
     random_state=42
 )

# %%
df=pd.DataFrame(x,columns=['feature1','feature2'])

# %%
df['target']=y

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='feature1',y='feature2',hue='target',data=df,palette='viridis',s=100,alpha=0.7)
plt.title('Synthetic Binary Classification Dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True,linestyle='-.',alpha=0.6)
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print(f'training set size:{x_train.shape[0]}samples')
print(f'testing set size:{x_test.shape[0]}samples')
# Out:
# training set size:700samples
# testing set size:300samples

# %%
model=LogisticRegression(random_state=42)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
print("Model trainig complete.")
# Out:
# Model trainig complete.

# %%
y_pred=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
conf_report=confusion_matrix(y_test,y_pred)
class_report=classification_report(y_test,y_pred)

# %%
print(f'Accuracy:{accuracy:.4f}')
print('\nConfusion Matrix:')
print(conf_report)
print('\nClassification Report:')
print(class_report)
# Out:
# Accuracy:0.8833
#
# Confusion Matrix:
# [[137  10]
#  [ 25 128]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       147
#            1       0.93      0.84      0.88       153
#
#     accuracy                           0.88       300
#    macro avg       0.89      0.88      0.88       300
# weighted avg       0.89      0.88      0.88       300

# %% [markdown]
# # VIsulaize the confusion matrix

# %%
 plt.figure(figsize=(6,5))
sns.heatmap(conf_report,annot=True,fmt='d',cmap='Blues',cbar=False,xticklabels=['predicted 0','predicted 1'],yticklabels=['Actual 0','Actuals 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
