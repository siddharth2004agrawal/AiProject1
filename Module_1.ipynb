# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharth2004agrawal/AiProject1/blob/AiModules%2Fproject/Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+4
# Out:
# 6

# %% [markdown]
# # Python for AI

# %%
print("Hello AI")
# Out:
# Hello AI

# %%
print('Hello AI')
# Out:
# Hello AI

# %%
'hello Ai'
# Out:
# 'hello Ai'

# %%
name='Siddharth'
print("heloo",name)
# Out:
# heloo Siddharth

# %%
name=input("enter your name")
print("Goodmorning",name)
# Out:
# enter your nameSiddharth
# Goodmorning Siddharth

# %%
age=int (input("enter your age"))
print("your age is",age+2)
# Out:
# enter your age24
# your age is 26

# %% [markdown]
# # Dataset uploading

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/AI_Survey_VAC.xlsx")

# %%
df
# Out:
#                   Timestamp              Name   Age   Daily Mobile Usage   \
# 0   2026-06-17 21:00:33.625   Dr. Divya Mishra    29                    4
# 1   2026-06-18 12:18:01.826       Vansh Tomer     20                    8
# 2   2026-06-18 12:18:04.614    Lavish chauhan     23                    1
# 3   2026-06-18 12:18:04.829   Utkarsh Chaubey     22                    5
# 4   2026-06-18 12:18:07.873   Harshit Upadhyay    21                    2
# ..                      ...                ...   ...                  ...
# 138 2026-06-18 12:21:37.766      Tushar  kumar    22                    3
# 139 2026-06-18 12:21:50.169  Govind Kumar Jha     20                    2
# 140 2026-06-18 12:21:57.362               manu    23                    8
# 141 2026-06-18 12:21:58.449         Shambhavi     22                    1
# 142 2026-06-18 12:22:21.994        Vikas kumar    22                    2
#
#      Study Hours
# 0               4
# 1               1
# 2               3
# ...

# %%
df=pd.read_csv("/content/AI_Survey_VAC.csv")

# %%
df
# Out:
#               Timestamp              Name   Age   Daily Mobile Usage   \
# 0    6/17/2026 21:00:34   Dr. Divya Mishra    29                    4
# 1    6/18/2026 12:18:02       Vansh Tomer     20                    8
# 2    6/18/2026 12:18:05    Lavish chauhan     23                    1
# 3    6/18/2026 12:18:05   Utkarsh Chaubey     22                    5
# 4    6/18/2026 12:18:08   Harshit Upadhyay    21                    2
# ..                  ...                ...   ...                  ...
# 139  6/18/2026 12:21:50  Govind Kumar Jha     20                    2
# 140  6/18/2026 12:21:57               manu    23                    8
# 141  6/18/2026 12:21:58         Shambhavi     22                    1
# 142  6/18/2026 12:22:22        Vikas kumar    22                    2
# 143  6/18/2026 12:22:36     Tatya Bichhoo     29                    8
#
#      Study Hours
# 0               4
# 1               1
# 2               3
# 3               6
# 4               4
# ...

# %% [markdown]
# # Check & count the missing value in each column

# %%
df.isnull().sum()
# Out:
# Timestamp              0
# Name                   0
# Age                    1
# Daily Mobile Usage     0
# Study Hours            0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                  Timestamp           Name   Age   Daily Mobile Usage   \
# 18 2026-06-18 12:18:21.734  Suyash Jaiswal   NaN                    8
#
#     Study Hours
# 18            12

# %%
df.head()
# Out:
#                 Timestamp             Name   Age   Daily Mobile Usage   \
# 0 2026-06-17 21:00:33.625  Dr. Divya Mishra  29.0                    4
# 1 2026-06-18 12:18:01.826      Vansh Tomer   20.0                    8
# 2 2026-06-18 12:18:04.614   Lavish chauhan   23.0                    1
# 3 2026-06-18 12:18:04.829  Utkarsh Chaubey   22.0                    5
# 4 2026-06-18 12:18:07.873  Harshit Upadhyay  21.0                    2
#
#    Study Hours
# 0             4
# 1             1
# 2             3
# 3             6
# 4             4

# %%
df.tail(9)
# Out:
#                   Timestamp              Name   Age   Daily Mobile Usage   \
# 134 2026-06-18 12:20:42.156      Arnav Mishra   21.0                    7
# 135 2026-06-18 12:21:16.324          Raja babu  29.0                    8
# 136 2026-06-18 12:21:23.521        Rahul Gupta  22.0                    8
# 137 2026-06-18 12:21:34.437  paridhi chaudhary  23.0                    5
# 138 2026-06-18 12:21:37.766      Tushar  kumar  22.0                    3
# 139 2026-06-18 12:21:50.169  Govind Kumar Jha   20.0                    2
# 140 2026-06-18 12:21:57.362               manu  23.0                    8
# 141 2026-06-18 12:21:58.449         Shambhavi   22.0                    1
# 142 2026-06-18 12:22:21.994        Vikas kumar  22.0                    2
#
#      Study Hours
# 134             1
# 135            12
# 136             2
# 137             5
# 138             1
# 139             4
# 140             1
# 141             4
# 142             4

# %%
df.shape
# Out:
# (143, 5)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Name ', 'Age ', 'Daily Mobile Usage ', 'Study Hours '], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            143 non-null    datetime64[ns]
#  1   Name                 143 non-null    object
#  2   Age                  142 non-null    float64
#  3   Daily Mobile Usage   143 non-null    int64
#  4   Study Hours          143 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 5.7+ KB

# %%
df.describe()
# Out:
#                            Timestamp        Age   Daily Mobile Usage   \
# count                            143  142.000000           143.000000
# mean      2026-06-18 12:12:46.300832   22.218310             4.377622
# min       2026-06-17 21:00:33.625000   19.000000             1.000000
# 25%       2026-06-18 12:18:37.920000   21.000000             3.000000
# 50%    2026-06-18 12:18:57.870000128   22.000000             4.000000
# 75%    2026-06-18 12:19:31.198499840   23.000000             6.000000
# max       2026-06-18 12:22:21.994000   29.000000             8.000000
# std                              NaN    1.684793             2.318949
#
#        Study Hours
# count    143.000000
# mean       4.279720
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max       12.000000
# std        2.715126

# %% [markdown]
# # Machine learning Hybridization and optimization for intelligent Application

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # load the dataset

# %%
df=pd.read_csv("/content/AI_Survey_VAC.csv")

# %%
df
# Out:
#               Timestamp              Name   Age   Daily Mobile Usage   \
# 0    6/17/2026 21:00:34   Dr. Divya Mishra    29                    4
# 1    6/18/2026 12:18:02       Vansh Tomer     20                    8
# 2    6/18/2026 12:18:05    Lavish chauhan     23                    1
# 3    6/18/2026 12:18:05   Utkarsh Chaubey     22                    5
# 4    6/18/2026 12:18:08   Harshit Upadhyay    21                    2
# ..                  ...                ...   ...                  ...
# 139  6/18/2026 12:21:50  Govind Kumar Jha     20                    2
# 140  6/18/2026 12:21:57               manu    23                    8
# 141  6/18/2026 12:21:58         Shambhavi     22                    1
# 142  6/18/2026 12:22:22        Vikas kumar    22                    2
# 143  6/18/2026 12:22:36     Tatya Bichhoo     29                    8
#
#      Study Hours
# 0               4
# 1               1
# 2               3
# 3               6
# 4               4
# ...

# %%
print("Dataset shape:",df.shape)
# Out:
# Dataset shape: (144, 5)

# %%
print("\nFirst 5 rows:")
# Out:
# First 5 rows:

# %%
print(df.head())
# Out:
#             Timestamp             Name   Age   Daily Mobile Usage   \
# 0  6/17/2026 21:00:34  Dr. Divya Mishra    29                    4
# 1  6/18/2026 12:18:02      Vansh Tomer     20                    8
# 2  6/18/2026 12:18:05   Lavish chauhan     23                    1
# 3  6/18/2026 12:18:05  Utkarsh Chaubey     22                    5
# 4  6/18/2026 12:18:08  Harshit Upadhyay    21                    2
#
#    Study Hours
# 0             4
# 1             1
# 2             3
# 3             6
# 4             4

# %%
print("\ndatset Info:")
# Out:
# datset Info:

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            144 non-null    object
#  1   Name                 144 non-null    object
#  2   Age                  144 non-null    int64
#  3   Daily Mobile Usage   144 non-null    int64
#  4   Study Hours          144 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 5.8+ KB
# None

# %%
print("\nBasic Statistics:")
# Out:
# Basic Statistics:

# %%
print(df.describe())
# Out:
#              Age   Daily Mobile Usage   Study Hours
# count  144.000000           144.000000    144.000000
# mean    22.263889             4.402778      4.256944
# std      1.765980             2.330459      2.719385
# min     19.000000             1.000000      1.000000
# 25%     21.000000             3.000000      2.750000
# 50%     22.000000             4.000000      4.000000
# 75%     23.000000             6.000000      5.000000
# max     29.000000             8.000000     12.000000

# %% [markdown]
# # Dataset Cleaning

# %%
print("missing values")
# Out:
# missing values

# %%
print(df.isnull().sum())
# Out:
# Timestamp              0
# Name                   0
# Age                    0
# Daily Mobile Usage     0
# Study Hours            0
# dtype: int64

# %%
print(f"\nDuplicate rows:{df.duplicated().sum()}")
# Out:
# Duplicate rows:0

# %%
df.columns=df.columns.str.strip()

# %%
print("\n Data Types:")
# Out:
#  Data Types:

# %%
print(df.dtypes)
# Out:
# Timestamp             object
# Name                  object
# Age                    int64
# Daily Mobile Usage     int64
# Study Hours            int64
# dtype: object

# %%
df['Age']=df['Age'].astype(int)

# %% [markdown]
# # Data analysis with NumPy & Pandas

# %%
print("===Statistical Summary==")
# Out:
# ===Statistical Summary==

# %%
print("\nMean values:")
# Out:
# Mean values:

# %%
print(df[['Age','Daily Mobile Usage','Study Hours']].mean())
# Out:
# Age                   22.263889
# Daily Mobile Usage     4.402778
# Study Hours            4.256944
# dtype: float64

# %%
print(df[['Age','Daily Mobile Usage','Study Hours']].median())
# Out:
# Age                   22.0
# Daily Mobile Usage     4.0
# Study Hours            4.0
# dtype: float64

# %%
print("\nMode Values:")
# Out:
# Mode Values:

# %%
print(df[['Age','Daily Mobile Usage','Study Hours']].mode().iloc[0])
# Out:
# Age                   22
# Daily Mobile Usage     8
# Study Hours            4
# Name: 0, dtype: int64

# %%
correlation=df[['Age','Daily Mobile Usage','Study Hours']].corr()

# %%
print("\nCorrelation Matrix:")
# Out:
# Correlation Matrix:

# %%
print(correlation)
# Out:
#                          Age  Daily Mobile Usage  Study Hours
# Age                 1.000000            0.242462     0.259539
# Daily Mobile Usage  0.242462            1.000000     0.125900
# Study Hours         0.259539            0.125900     1.000000

# %%
df['Mobile Usage Category']=pd.cut(df['Daily Mobile Usage'],
bins=[0,2,4,6,8,12],labels=['Very low','Low','Medium','High','Very High'])

# %%
df
# Out:
#               Timestamp               Name  Age  Daily Mobile Usage  \
# 0    6/17/2026 21:00:34   Dr. Divya Mishra   29                   4
# 1    6/18/2026 12:18:02       Vansh Tomer    20                   8
# 2    6/18/2026 12:18:05    Lavish chauhan    23                   1
# 3    6/18/2026 12:18:05   Utkarsh Chaubey    22                   5
# 4    6/18/2026 12:18:08   Harshit Upadhyay   21                   2
# ..                  ...                ...  ...                 ...
# 139  6/18/2026 12:21:50  Govind Kumar Jha    20                   2
# 140  6/18/2026 12:21:57               manu   23                   8
# 141  6/18/2026 12:21:58         Shambhavi    22                   1
# 142  6/18/2026 12:22:22        Vikas kumar   22                   2
# 143  6/18/2026 12:22:36     Tatya Bichhoo    29                   8
#
#      Study Hours Mobile Usage Category
# 0              4                   Low
# 1              1                  High
# ...

# %%
print(df['Mobile Usage Category'].value_counts())
# Out:
# Mobile Usage Category
# Low          47
# Very low     35
# High         34
# Medium       28
# Very High     0
# Name: count, dtype: int64

# %% [markdown]
# Dataset Visualization

# %%
plt.style.use('seaborn-v0_8-darkgrid')

# %%
sns.set_palette("husl")

# %%
fig=plt.figure(figsize=(18,12))

# %%
plt.subplot(2,3,1)
# Out:
# <Axes: >

# %%
sns.histplot(df['Age'],bins=15,kde=True)
plt.title(' Distribution of Age',fontsize=14,fontweight='bold')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.subplot(2,3,2)
# Out:
# <Axes: >

# %%
sns.histplot(df['Daily Mobile Usage'],bins=10,kde=True)
plt.title(' Distribution of Daily Mobile Usage(hours)',fontsize=14,fontweight='bold')
plt.xlabel('Daily Mobile Usage(hours)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
